# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                  
from random import randint               
import tensorflow.keras.layers as Layers
import tensorflow.keras.activations as Actications
import tensorflow.keras.models as Models
import tensorflow.keras.optimizers as Optimizer
import tensorflow.keras.metrics as Metrics
import tensorflow.keras.utils as Utils
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from keras.models import Sequential  
import tensorflow as tf
from tqdm import tqdm

# %%
class_names = ['angry', 'shock', 'normal', 'smile']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)
IMAGE_SIZE = (120, 120)

# %%
def load_data():
    """
        Load the data:
            - 400 images to train the network.
            - 80 images to evaluate how accurately the network learned to classify images.
    """
    filters = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
    datasets = ['dataset_iron/train', 'dataset_iron/test']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE)
                image = cv2.filter2D(image,-1,filters)
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
#  24%|███████████████████▏                                                            | 24/100 [00:00<00:00, 235.92it/s]
# Loading dataset_iron/train
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 234.27it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 248.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 233.43it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 247.12it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 224.03it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 233.18it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
# Loading dataset_iron/test
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 213.33it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 220.36it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %%
# Exploring Datasets

n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of Class: {}".format(nb_classes))
print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of Class: 4
# Number of training examples: 400
# Number of testing examples: 80
# Each image is of size: (120, 120)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%'
        )
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
# Data Normalization

train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
# Visualize the Data

def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %%
def display_examples(class_names, images, labels):
    """
        Display 25 images from the images array with its corresponding labels
    """
    
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()

# %%
display_examples(class_names, train_images, train_labels)

# %%
# CNN models

model = Models.Sequential()

# CNN Architecture

model.add(Layers.Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(120, 120, 3)))
model.add(Layers.MaxPool2D(2,2))
model.add(Layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(2,2))
model.add(Layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(2,2))
model.add(Layers.Conv2D(256,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(2,2))

# ANN Architecture

model.add(Layers.Flatten())

model.add(Layers.Dropout(0.2))
model.add(Layers.Dense(1000, activation='relu'))

model.add(Layers.Dense(4, activation='softmax'))

# Compiling Model

model.compile(optimizer=Optimizer.Adam(lr=0.00001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 118, 118, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 59, 59, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 57, 57, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              6401000
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4004
# =================================================================
# Total params: 6,793,420
# Trainable params: 6,793,420
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time

# START OF TIME
start = time.time()

### MODEL FITTING
history = model.fit(train_images, 
                    train_labels, 
                    batch_size= 16, 
                    epochs= 120,
                    validation_split=0.2
                    )
### MODEL FITTING

# END OF TIME
end = time.time()

# RESULT
print("Time elapsed for this training section: {0:.2f}s".format(end - start))

# EPOCHS RUNTIME

# 30 Epochs = 75.09s
# 60 Epochs = 147.97s
# 90 Epochs = 220.01s
# 120 Epochs = 292.42
# Out:
# Epoch 1/120
# 20/20 [==============================] - 6s 171ms/step - loss: 1.3918 - accuracy: 0.2184 - val_loss: 1.3694 - val_accuracy: 0.2625
# Epoch 2/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.3594 - accuracy: 0.3641 - val_loss: 1.3409 - val_accuracy: 0.4750
# Epoch 3/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.3345 - accuracy: 0.5160 - val_loss: 1.3064 - val_accuracy: 0.5125
# Epoch 4/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.3025 - accuracy: 0.5711 - val_loss: 1.2665 - val_accuracy: 0.5125
# Epoch 5/120
# 20/20 [==============================] - 2s 121ms/step - loss: 1.2598 - accuracy: 0.6214 - val_loss: 1.2146 - val_accuracy: 0.5750
# Epoch 6/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.2167 - accuracy: 0.5968 - val_loss: 1.1492 - val_accuracy: 0.6125
# Epoch 7/120
# 20/20 [==============================] - 2s 121ms/step - loss: 1.1503 - accuracy: 0.6215 - val_loss: 1.0768 - val_accuracy: 0.6625
# Epoch 8/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.0835 - accuracy: 0.6511 - val_loss: 1.0045 - val_accuracy: 0.6250
# Epoch 9/120
# 20/20 [==============================] - 2s 121ms/step - loss: 1.0190 - accuracy: 0.6292 - val_loss: 0.9287 - val_accuracy: 0.6625
# Epoch 10/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.9341 - accuracy: 0.7437 - val_loss: 0.8590 - val_accuracy: 0.7125
# Epoch 11/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.8789 - accuracy: 0.7382 - val_loss: 0.7877 - val_accuracy: 0.8125
# Epoch 12/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.8652 - accuracy: 0.6992 - val_loss: 0.7821 - val_accuracy: 0.5875
# Epoch 13/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.7866 - accuracy: 0.6609 - val_loss: 0.6975 - val_accuracy: 0.8875
# Epoch 14/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.6914 - accuracy: 0.7924 - val_loss: 0.6525 - val_accuracy: 0.8625
# Epoch 15/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.6753 - accuracy: 0.8115 - val_loss: 0.6332 - val_accuracy: 0.8500
# Epoch 16/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.6350 - accuracy: 0.8348 - val_loss: 0.6170 - val_accuracy: 0.8250
# Epoch 17/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.6508 - accuracy: 0.8144 - val_loss: 0.5817 - val_accuracy: 0.8500
# Epoch 18/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.6282 - accuracy: 0.8373 - val_loss: 0.5500 - val_accuracy: 0.8625
# Epoch 19/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.5871 - accuracy: 0.8279 - val_loss: 0.5173 - val_accuracy: 0.9375
# Epoch 20/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.5583 - accuracy: 0.8491 - val_loss: 0.5074 - val_accuracy: 0.8875
# Epoch 21/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.5410 - accuracy: 0.8606 - val_loss: 0.4871 - val_accuracy: 0.8625
# Epoch 22/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.4831 - accuracy: 0.9074 - val_loss: 0.4666 - val_accuracy: 0.8750
# Epoch 23/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.4851 - accuracy: 0.8612 - val_loss: 0.4387 - val_accuracy: 0.9375
# Epoch 24/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.4654 - accuracy: 0.8715 - val_loss: 0.4085 - val_accuracy: 0.9375
# Epoch 25/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0
120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0364 - accuracy: 0.9949 - val_loss: 0.0382 - val_accuracy: 1.0000
# Epoch 87/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0436 - accuracy: 0.9969 - val_loss: 0.0346 - val_accuracy: 1.0000
# Epoch 88/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0360 - accuracy: 0.9995 - val_loss: 0.0379 - val_accuracy: 0.9875
# Epoch 89/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0329 - accuracy: 0.9990 - val_loss: 0.0375 - val_accuracy: 0.9875
# Epoch 90/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 1.0000
# Epoch 91/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0391 - accuracy: 0.9964 - val_loss: 0.0339 - val_accuracy: 1.0000
# Epoch 92/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0324 - accuracy: 0.9988 - val_loss: 0.0382 - val_accuracy: 0.9875
# Epoch 93/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0385 - accuracy: 0.9946 - val_loss: 0.0370 - val_accuracy: 0.9875
# Epoch 94/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 1.0000
# Epoch 95/120
# 20/20 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 1.00 - 2s 121ms/step - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 1.0000
# Epoch 96/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0239 - accuracy: 0.9981 - val_loss: 0.0284 - val_accuracy: 1.0000
# Epoch 97/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 98/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 99/120
# 20/20 [==============================] - 2s 122ms/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.0322 - val_accuracy: 0.9875
# Epoch 100/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0308 - accuracy: 0.9875 - val_loss: 0.0299 - val_accuracy: 1.0000
# Epoch 101/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 1.0000
# Epoch 102/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 103/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0276 - accuracy: 0.9984 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 104/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 1.0000
# Epoch 105/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 106/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 1.0000
# Epoch 107/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 108/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 109/120
# 20/20 [==============================] - 2s 122ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 1.0000
# Epoch 110/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 111/120
# 20/20 [==============================] - 2s 122ms/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 112/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 113/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 114/120
# 20/20 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 1.00 - 2s 121ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 115/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0186 - accuracy: 0.9972 - val_loss: 0.0150 - val_accuracy: 1.0000
# Epoch 116/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 117/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 1.0000
# Epoch 118/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 119/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 1.0000
# Epoch 120/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 1.0000
# Time elapsed for this training section: 292.42s

# %%
def plot_accuracy_loss(history):
    """
        Plot the accuracy and the loss during the training of the nn.
    """
    fig = plt.figure(figsize=(20,10))

    # Plot accuracy
    plt.subplot(221)
    plt.plot(history.history['accuracy'],'bo--', label = "acc")
    plt.plot(history.history['val_accuracy'], 'ro--', label = "val_acc")
    plt.title("train_acc vs val_acc")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()

    # Plot loss function
    plt.subplot(222)
    plt.plot(history.history['loss'],'bo--', label = "loss")
    plt.plot(history.history['val_loss'], 'ro--', label = "val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %%
plot_accuracy_loss(history)

# %%
loss, acc = model.evaluate(test_images, test_labels)

print("System Accuracy : {0:.2f}%".format(acc*100))
print("System Loss : {0:.5f}".format(loss))

# 30 Epochs, Accuracy = 86.25%
# 60 Epochs, Accuracy = 96.25% 
# 90 Epochs, Accuracy = 97.50%
# 120 Epochs Accuracy = 98.75%
# Out:
# 3/3 [==============================] - 1s 45ms/step - loss: 0.0358 - accuracy: 0.9875
# System Accuracy : 98.75%
# System Loss : 0.03578

# %%
predictions = model.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, test_images, pred_labels)

# %%
def print_mislabeled_images(class_names, test_images, test_labels, pred_labels):
    """
        Print 25 examples of mislabeled images by the classifier, e.g when test_labels != pred_labels
    """
    BOO = (test_labels == pred_labels)
    mislabeled_indices = np.where(BOO == 0)
    mislabeled_images = test_images[mislabeled_indices]
    mislabeled_labels = pred_labels[mislabeled_indices]

    title = "Some examples of mislabeled images by the classifier:"
    display_examples(class_names,  mislabeled_images, mislabeled_labels)

# %%
print_mislabeled_images(class_names, test_images, test_labels, pred_labels)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-40a0c23fa227> in <module>
# ----> 1 print_mislabeled_images(class_names, test_images, test_labels, pred_labels)
#
# <ipython-input-21-2b9596ee27de> in print_mislabeled_images(class_names, test_images, test_labels, pred_labels)
#       9
#      10     title = "Some examples of mislabeled images by the classifier:"
# ---> 11     display_examples(class_names,  mislabeled_images, mislabeled_labels)
#
# <ipython-input-12-cb91593e2983> in display_examples(class_names, images, labels)
#      11         plt.yticks([])
#      12         plt.grid(False)
# ---> 13         plt.imshow(images[i], cmap=plt.cm.binary)
#      14         plt.xlabel(class_names[labels[i]])
#      15     plt.show()
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sn.heatmap(CM, annot=True, 
           annot_kws={"size": 10}, 
           xticklabels=class_names, 
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()
