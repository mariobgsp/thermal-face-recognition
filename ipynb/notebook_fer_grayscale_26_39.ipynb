# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                  
from random import randint               
import tensorflow.keras.layers as Layers
import tensorflow.keras.activations as Actications
import tensorflow.keras.models as Models
import tensorflow.keras.optimizers as Optimizer
import tensorflow.keras.metrics as Metrics
import tensorflow.keras.utils as Utils
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from keras.models import Sequential  
import tensorflow as tf
from tqdm import tqdm

# %%
class_names = ['angry', 'shock', 'normal', 'smile']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)
IMAGE_SIZE = (120, 120)

# %%
def load_data():
    """
        Load the data:
            - 400 images to train the network.
            - 80 images to evaluate how accurately the network learned to classify images.
    """
    filters = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
    datasets = ['dataset_fe_grayscale/train', 'dataset_fe_grayscale/test']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE)
                image = cv2.filter2D(image,-1,filters)
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
#  17%|█████████████▌                                                                  | 17/100 [00:00<00:00, 167.18it/s]
# Loading dataset_fe_grayscale/train
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 213.71it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 251.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 241.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 245.98it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 245.07it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 241.80it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
# Loading dataset_fe_grayscale/test
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 221.75it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 246.22it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %%
# Exploring Datasets

n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of Class: {}".format(nb_classes))
print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of Class: 4
# Number of training examples: 400
# Number of testing examples: 80
# Each image is of size: (120, 120)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%'
        )
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
# Data Normalization

train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
# Visualize the Data

def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %%
def display_examples(class_names, images, labels):
    """
        Display 25 images from the images array with its corresponding labels
    """
    
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()

# %%
display_examples(class_names, train_images, train_labels)

# %%
# CNN models

model = Models.Sequential()

# CNN Architecture

model.add(Layers.Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(120, 120, 3)))
model.add(Layers.MaxPool2D(2,2))
model.add(Layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(2,2))
model.add(Layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(2,2))
model.add(Layers.Conv2D(256,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(2,2))

# ANN Architecture

model.add(Layers.Flatten())

model.add(Layers.Dropout(0.2))
model.add(Layers.Dense(1000, activation='relu'))

model.add(Layers.Dense(4, activation='softmax'))

# Compiling Model

model.compile(optimizer=Optimizer.Adam(lr=0.00001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 118, 118, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 59, 59, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 57, 57, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              6401000
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4004
# =================================================================
# Total params: 6,793,420
# Trainable params: 6,793,420
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time

# START OF TIME
start = time.time()

### MODEL FITTING
history = model.fit(train_images, 
                    train_labels, 
                    batch_size= 16, 
                    epochs= 60,
                    validation_split=0.2
                    )
### MODEL FITTING

# END OF TIME
end = time.time()

# RESULT
print("Time elapsed for this training section: {0:.2f}s".format(end - start))

# EPOCHS RUNTIME

# 30 Epochs = 79.94s
# 60 Epochs = 147.64s
# 90 Epochs = 220.84s
# 120 Epochs = 291.01s
# Out:
# Epoch 1/60
# 20/20 [==============================] - 9s 187ms/step - loss: 1.3839 - accuracy: 0.2840 - val_loss: 1.3726 - val_accuracy: 0.2750
# Epoch 2/60
# 20/20 [==============================] - 2s 120ms/step - loss: 1.3757 - accuracy: 0.3136 - val_loss: 1.3616 - val_accuracy: 0.6000
# Epoch 3/60
# 20/20 [==============================] - 2s 121ms/step - loss: 1.3564 - accuracy: 0.5615 - val_loss: 1.3481 - val_accuracy: 0.4250
# Epoch 4/60
# 20/20 [==============================] - 2s 119ms/step - loss: 1.3428 - accuracy: 0.5290 - val_loss: 1.3300 - val_accuracy: 0.4375
# Epoch 5/60
# 20/20 [==============================] - 2s 120ms/step - loss: 1.3217 - accuracy: 0.5678 - val_loss: 1.3068 - val_accuracy: 0.4750
# Epoch 6/60
# 20/20 [==============================] - 2s 120ms/step - loss: 1.3039 - accuracy: 0.5838 - val_loss: 1.2766 - val_accuracy: 0.8000
# Epoch 7/60
# 20/20 [==============================] - 2s 120ms/step - loss: 1.2739 - accuracy: 0.8273 - val_loss: 1.2451 - val_accuracy: 0.7875
# Epoch 8/60
# 20/20 [==============================] - 2s 119ms/step - loss: 1.2430 - accuracy: 0.8411 - val_loss: 1.1992 - val_accuracy: 0.9250
# Epoch 9/60
# 20/20 [==============================] - 2s 120ms/step - loss: 1.2035 - accuracy: 0.8729 - val_loss: 1.1456 - val_accuracy: 0.9125
# Epoch 10/60
# 20/20 [==============================] - 2s 120ms/step - loss: 1.1480 - accuracy: 0.8498 - val_loss: 1.0879 - val_accuracy: 0.8875
# Epoch 11/60
# 20/20 [==============================] - 2s 120ms/step - loss: 1.0964 - accuracy: 0.9062 - val_loss: 1.0096 - val_accuracy: 0.9125
# Epoch 12/60
# 20/20 [==============================] - 2s 120ms/step - loss: 1.0282 - accuracy: 0.8624 - val_loss: 0.9376 - val_accuracy: 0.8750
# Epoch 13/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.9596 - accuracy: 0.8719 - val_loss: 0.8697 - val_accuracy: 0.8750
# Epoch 14/60
# 20/20 [==============================] - 2s 122ms/step - loss: 0.8660 - accuracy: 0.8784 - val_loss: 0.7905 - val_accuracy: 0.9125
# Epoch 15/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.7982 - accuracy: 0.8835 - val_loss: 0.7358 - val_accuracy: 0.8750
# Epoch 16/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.7313 - accuracy: 0.8650 - val_loss: 0.6454 - val_accuracy: 0.9125
# Epoch 17/60
# 20/20 [==============================] - 2s 122ms/step - loss: 0.7222 - accuracy: 0.8758 - val_loss: 0.5937 - val_accuracy: 0.8750
# Epoch 18/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.6149 - accuracy: 0.9009 - val_loss: 0.5334 - val_accuracy: 0.9000
# Epoch 19/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.5441 - accuracy: 0.8984 - val_loss: 0.5227 - val_accuracy: 0.9125
# Epoch 20/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.5206 - accuracy: 0.9105 - val_loss: 0.4390 - val_accuracy: 0.9125
# Epoch 21/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.4799 - accuracy: 0.8961 - val_loss: 0.4055 - val_accuracy: 0.9125
# Epoch 22/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.4300 - accuracy: 0.9044 - val_loss: 0.3663 - val_accuracy: 0.9250
# Epoch 23/60
# 20/20 [==============================] - 2s 121ms/step - loss: 0.3927 - accuracy: 0.9269 - val_loss: 0.3462 - val_accuracy: 0.9250
# Epoch 24/60
# 20/20 [==============================] - 2s 121ms/step - loss: 0.3595 - accuracy: 0.8804 - val_loss: 0.3178 - val_accuracy: 0.9500
# Epoch 25/60
# 20/20 [==============================] - 2s 121ms/step - loss: 0.3543 - accuracy: 0.9222 - val_loss: 0.3132 - val_accuracy: 0.9625
# Epoch 26/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2815 - accuracy: 0.9555 - val_loss: 0.3253 - val_accuracy: 0.9125
# Epoch 27/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.3028 - accuracy: 0.9510 - val_loss: 0.2505 - val_accuracy: 0.9375
# Epoch 28/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2792 - accuracy: 0.9603 - val_loss: 0.2600 - val_accuracy: 0.9125
# Epoch 29/60
# 20/20 [==============================] - 2s 122ms/step - loss: 0.2594 - accuracy: 0.9406 - val_loss: 0.2257 - val_accuracy: 0.9375
# Epoch 30/60
# 20/20 [==============================] - 2s 122ms/step - loss: 0.2522 - accuracy: 0.9114 - val_loss: 0.2129 - val_accuracy: 0.9250
# Epoch 31/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2121 - accuracy: 0.9571 - val_loss: 0.1929 - val_accuracy: 0.9375
# Epoch 32/60
# 20/20 [==============================] - 2s 119ms/step - loss: 0.1993 - accuracy: 0.9526 - val_loss: 0.2070 - val_accuracy: 0.9500
# Epoch 33/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2384 - accuracy: 0.9318 - val_loss: 0.1815 - val_accuracy: 0.9625
# Epoch 34/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2003 - accuracy: 0.9630 - val_loss: 0.1580 - val_accuracy: 0.9625
# Epoch 35/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1523 - accuracy: 0.9839 - val_loss: 0.1447 - val_accuracy: 0.9625
# Epoch 36/60
# 20/20 [==============================] - 2s 119ms/step - loss: 0.1440 - accuracy: 0.9823 - val_loss: 0.1448 - val_accuracy: 0.9625
# Epoch 37/60
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1469 - accuracy: 0.9876 - val_loss: 0.1308 - val_accuracy: 0.9500
# Epoch 38/60
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1415 - accuracy: 0.9636 - val_loss: 0.1166 - val_accuracy: 0.9875
# Epoch 39/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1364 - accuracy: 0.9762 - val_loss: 0.1343 - val_accuracy: 0.9500
# Epoch 40/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1133 - accuracy: 0.9761 - val_loss: 0.1024 - val_accuracy: 1.0000
# Epoch 41/60
# 20/20 [==============================] - 2s 122ms/step - loss: 0.1124 - accuracy: 0.9885 - val_loss: 0.1052 - val_accuracy: 0.9625
# Epoch 42/60
# 20/20 [==============================] - 2s 122ms/step - loss: 0.1077 - accuracy: 0.9917 - val_loss: 0.0954 - val_accuracy: 0.9875
# Epoch 43/60
# 20/20 [==============================] - 2s 123ms/step - loss: 0.0914 - accuracy: 0.9819 - val_loss: 0.0918 - val_accuracy: 0.9750
# Epoch 44/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0770 - accuracy: 0.9985 - val_loss: 0.0817 - val_accuracy: 1.0000
# Epoch 45/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1147 - accuracy: 0.9693 - val_loss: 0.0823 - val_accuracy: 0.9875
# Epoch 46/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0943 - accuracy: 0.9856 - val_loss: 0.0699 - val_accuracy: 1.0000
# Epoch 47/60
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0874 - accuracy: 0.9921 - val_loss: 0.0755 - val_accuracy: 0.9750
# Epoch 48/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0726 - accuracy: 0.9875 - val_loss: 0.0653 - val_accuracy: 1.0000
# Epoch 49/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0746 - accuracy: 0.9840 - val_loss: 0.0566 - val_accuracy: 1.0000
# Epoch 50/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0553 - accuracy: 0.9929 - val_loss: 0.0625 - val_accuracy: 1.0000
# Epoch 51/60
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0748 - accuracy: 0.9919 - val_loss: 0.0620 - val_accuracy: 1.0000
# Epoch 52/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0609 - accuracy: 0.9958 - val_loss: 0.0521 - val_accuracy: 1.0000
# Epoch 53/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0611 - accuracy: 0.9964 - val_loss: 0.0439 - val_accuracy: 1.0000
# Epoch 54/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0603 - accuracy: 0.9813 - val_loss: 0.0516 - val_accuracy: 1.0000
# Epoch 55/60
# 20/20 [==============================] - 2s 123ms/step - loss: 0.0515 - accuracy: 0.9971 - val_loss: 0.0501 - val_accuracy: 1.0000
# Epoch 56/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0482 - accuracy: 0.9922 - val_loss: 0.0388 - val_accuracy: 1.0000
# Epoch 57/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0476 - accuracy: 0.9984 - val_loss: 0.0416 - val_accuracy: 1.0000
# Epoch 58/60
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0416 - accuracy: 0.9976 - val_loss: 0.0355 - val_accuracy: 1.0000
# Epoch 59/60
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0400 - accuracy: 0.9933 - val_loss: 0.0387 - val_accuracy: 1.0000
# Epoch 60/60
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0406 - accuracy: 0.9932 - val_loss: 0.0332 - val_accuracy: 1.0000
# Time elapsed for this training section: 150.60s

# %%
def plot_accuracy_loss(history):
    """
        Plot the accuracy and the loss during the training of the nn.
    """
    fig = plt.figure(figsize=(20,10))

    # Plot accuracy
    plt.subplot(221)
    plt.plot(history.history['accuracy'],'bo--', label = "acc")
    plt.plot(history.history['val_accuracy'], 'ro--', label = "val_acc")
    plt.title("train_acc vs val_acc")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()

    # Plot loss function
    plt.subplot(222)
    plt.plot(history.history['loss'],'bo--', label = "loss")
    plt.plot(history.history['val_loss'], 'ro--', label = "val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %%
plot_accuracy_loss(history)

# %%
loss, acc = model.evaluate(test_images, test_labels)

print("System Accuracy : {0:.2f}%".format(acc*100))
print("System Loss : {0:.5f}".format(loss))

# 30 Epochs, Accuracy = 22.50%
# 60 Epochs, Accuracy = 12.50%
# 90 Epochs, Accuracy = 15.00%
# 120 Epochs Accuracy = 12.50%
# Out:
# 3/3 [==============================] - 1s 45ms/step - loss: 6.9634 - accuracy: 0.1250
# System Accuracy : 12.50%
# System Loss : 6.96345

# %%
predictions = model.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, test_images, pred_labels)

# %%
def print_mislabeled_images(class_names, test_images, test_labels, pred_labels):
    """
        Print 25 examples of mislabeled images by the classifier, e.g when test_labels != pred_labels
    """
    BOO = (test_labels == pred_labels)
    mislabeled_indices = np.where(BOO == 0)
    mislabeled_images = test_images[mislabeled_indices]
    mislabeled_labels = pred_labels[mislabeled_indices]

    title = "Some examples of mislabeled images by the classifier:"
    display_examples(class_names,  mislabeled_images, mislabeled_labels)

# %%
print_mislabeled_images(class_names, test_images, test_labels, pred_labels)

# %%
CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sn.heatmap(CM, annot=True, 
           annot_kws={"size": 10}, 
           xticklabels=class_names, 
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()
