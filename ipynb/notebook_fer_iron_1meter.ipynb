# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                  
from random import randint               
import tensorflow.keras.layers as Layers
import tensorflow.keras.activations as Actications
import tensorflow.keras.models as Models
import tensorflow.keras.optimizers as Optimizer
import tensorflow.keras.metrics as Metrics
import tensorflow.keras.utils as Utils
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from keras.models import Sequential  
import tensorflow as tf
from tqdm import tqdm

# %%
class_names = ['angry', 'shock', 'normal', 'smile']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)
IMAGE_SIZE = (120, 120)

# %%
def load_data():
    """
        Load the data:
            - 400 images to train the network.
            - 80 images to evaluate how accurately the network learned to classify images.
    """
    filters = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
    datasets = ['dataset_iron_1m/train', 'dataset_iron_1m/test']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE)
                image = cv2.filter2D(image,-1,filters)
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
#  25%|████████████████████                                                            | 25/100 [00:00<00:00, 243.37it/s]
# Loading dataset_iron_1m/train
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 231.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 266.44it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 263.52it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 248.31it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 260.44it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 267.39it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
# Loading dataset_iron_1m/test
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 267.39it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 270.99it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %%
# Exploring Datasets

n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of Class: {}".format(nb_classes))
print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of Class: 4
# Number of training examples: 400
# Number of testing examples: 80
# Each image is of size: (120, 120)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%'
        )
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
# Data Normalization

train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
# Visualize the Data

def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %%
def display_examples(class_names, images, labels):
    """
        Display 25 images from the images array with its corresponding labels
    """
    
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()

# %%
display_examples(class_names, train_images, train_labels)

# %%
# CNN models

model = Models.Sequential()

# CNN Architecture

model.add(Layers.Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(120, 120, 3)))
model.add(Layers.MaxPool2D(2,2))
model.add(Layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(2,2))
model.add(Layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(2,2))
model.add(Layers.Conv2D(256,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(2,2))

# ANN Architecture

model.add(Layers.Flatten())

model.add(Layers.Dropout(0.2))
model.add(Layers.Dense(1000, activation='relu'))

model.add(Layers.Dense(4, activation='softmax'))

# Compiling Model

model.compile(optimizer=Optimizer.Adam(lr=0.00001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 118, 118, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 59, 59, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 57, 57, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              6401000
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4004
# =================================================================
# Total params: 6,793,420
# Trainable params: 6,793,420
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time

# START OF TIME
start = time.time()

### MODEL FITTING
history = model.fit(train_images, 
                    train_labels, 
                    batch_size= 16, 
                    epochs= 120,
                    validation_split=0.2
                    )
### MODEL FITTING

# END OF TIME
end = time.time()

# RESULT
print("Time elapsed for this training section: {0:.2f}s".format(end - start))

# EPOCHS RUNTIME

# 30 Epochs = 75.61s
# 60 Epochs = 147.82s
# 90 Epochs = 220.07
# 120 Epochs = 292.83
# Out:
# Epoch 1/120
# 20/20 [==============================] - 7s 226ms/step - loss: 1.3865 - accuracy: 0.2731 - val_loss: 1.3862 - val_accuracy: 0.3000
# Epoch 2/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.3748 - accuracy: 0.3074 - val_loss: 1.3708 - val_accuracy: 0.4750
# Epoch 3/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.3720 - accuracy: 0.3959 - val_loss: 1.3607 - val_accuracy: 0.5000
# Epoch 4/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.3566 - accuracy: 0.5114 - val_loss: 1.3510 - val_accuracy: 0.4875
# Epoch 5/120
# 20/20 [==============================] - 2s 121ms/step - loss: 1.3494 - accuracy: 0.5542 - val_loss: 1.3364 - val_accuracy: 0.5250
# Epoch 6/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.3341 - accuracy: 0.5953 - val_loss: 1.3181 - val_accuracy: 0.6000
# Epoch 7/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.3105 - accuracy: 0.6620 - val_loss: 1.2963 - val_accuracy: 0.5875
# Epoch 8/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.2851 - accuracy: 0.5948 - val_loss: 1.2657 - val_accuracy: 0.6375
# Epoch 9/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.2656 - accuracy: 0.6027 - val_loss: 1.2290 - val_accuracy: 0.6375
# Epoch 10/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.2211 - accuracy: 0.5959 - val_loss: 1.1890 - val_accuracy: 0.6375
# Epoch 11/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.1667 - accuracy: 0.6538 - val_loss: 1.1378 - val_accuracy: 0.6375
# Epoch 12/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.1317 - accuracy: 0.6495 - val_loss: 1.0996 - val_accuracy: 0.6125
# Epoch 13/120
# 20/20 [==============================] - 2s 121ms/step - loss: 1.1084 - accuracy: 0.6224 - val_loss: 1.0428 - val_accuracy: 0.6375
# Epoch 14/120
# 20/20 [==============================] - 2s 120ms/step - loss: 1.0732 - accuracy: 0.5996 - val_loss: 0.9946 - val_accuracy: 0.6875
# Epoch 15/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.9972 - accuracy: 0.6456 - val_loss: 0.9597 - val_accuracy: 0.6250
# Epoch 16/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.9937 - accuracy: 0.6898 - val_loss: 0.9121 - val_accuracy: 0.6500
# Epoch 17/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.9292 - accuracy: 0.6734 - val_loss: 0.8621 - val_accuracy: 0.7125
# Epoch 18/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.8792 - accuracy: 0.6503 - val_loss: 0.8199 - val_accuracy: 0.6875
# Epoch 19/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.8927 - accuracy: 0.6765 - val_loss: 0.8177 - val_accuracy: 0.6875
# Epoch 20/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.8359 - accuracy: 0.6738 - val_loss: 0.7556 - val_accuracy: 0.7000
# Epoch 21/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.7855 - accuracy: 0.6948 - val_loss: 0.7411 - val_accuracy: 0.7500
# Epoch 22/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.7799 - accuracy: 0.7056 - val_loss: 0.6945 - val_accuracy: 0.7625
# Epoch 23/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.7897 - accuracy: 0.7179 - val_loss: 0.6932 - val_accuracy: 0.6750
# Epoch 24/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.7101 - accuracy: 0.7514 - val_loss: 0.6459 - val_accuracy: 0.7625
# Epoch 25/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.6952 - accuracy: 0.7559 - val_loss: 0.6488 - val_accuracy: 0.7875
# Epoch 26/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.7069 - accuracy: 0.7183 - val_loss: 0.6116 - val_accuracy: 0.8000
# Epoch 27/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.6825 - accuracy: 0.7764 - val_loss: 0.5923 - val_accuracy: 0.8000
# Epoch 28/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.6423 - accuracy: 0.7731 - val_loss: 0.5672 - val_accuracy: 0.8250
# Epoch 29/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.6427 - accuracy: 0.7660 - val_loss: 0.5388 - val_accuracy: 0.8250
# Epoch 30/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.5921 - accuracy: 0.7841 - val_loss: 0.5290 - val_accuracy: 0.8000
# Epoch 31/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.6275 - accuracy: 0.7582 - val_loss: 0.5260 - val_accuracy: 0.8000
# Epoch 32/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.5705 - accuracy: 0.8175 - val_loss: 0.4836 - val_accuracy: 0.8500
# Epoch 33/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.5495 - accuracy: 0.8058 - val_loss: 0.4891 - val_accuracy: 0.8750
# Epoch 34/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.5846 - accuracy: 0.7686 - val_loss: 0.4700 - val_accuracy: 0.8750
# Epoch 35/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.5030 - accuracy: 0.8145 - val_loss: 0.4336 - val_accuracy: 0.8750
# Epoch 36/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.4998 - accuracy: 0.8111 - val_loss: 0.4337 - val_accuracy: 0.8750
# Epoch 37/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.5149 - accuracy: 0.8368 - val_loss: 0.4202 - val_accuracy: 0.8750
# Epoch 38/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.4299 - accuracy: 0.8653 - val_loss: 0.3930 - val_accuracy: 0.8875
# Epoch 39/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.4418 - accuracy: 0.8480 - val_loss: 0.3769 - val_accuracy: 0.9250
# Epoch 40/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.4267 - accuracy: 0.8672 - val_loss: 0.3919 - val_accuracy: 0.8875
# Epoch 41/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.4269 - accuracy: 0.8664 - val_loss: 0.3457 - val_accuracy: 0.9250
# Epoch 42/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.3787 - accuracy: 0.9166 - val_loss: 0.3580 - val_accuracy: 0.9000
# Epoch 43/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.3978 - accuracy: 0.8538 - val_loss: 0.3293 - val_accuracy: 0.9375
# Epoch 44/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.3861 - accuracy: 0.8858 - val_loss: 0.3101 - val_accuracy: 0.9375
# Epoch 45/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.3501 - accuracy: 0.9003 - val_loss: 0.3011 - val_accuracy: 0.9375
# Epoch 46/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.3393 - accuracy: 0.8846 - val_loss: 0.2846 - val_accuracy: 0.9625
# Epoch 47/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.3289 - accuracy: 0.9110 - val_loss: 0.2877 - val_accuracy: 0.9500
# Epoch 48/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.3737 - accuracy: 0.8643 - val_loss: 0.2661 - val_accuracy: 0.9625
# Epoch 49/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.3195 - accuracy: 0.8889 - val_loss: 0.2918 - val_accuracy: 0.9125
# Epoch 50/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2970 - accuracy: 0.9266 - val_loss: 0.2479 - val_accuracy: 0.9875
# Epoch 51/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.2931 - accuracy: 0.9271 - val_loss: 0.2383 - val_accuracy: 0.9625
# Epoch 52/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2831 - accuracy: 0.9218 - val_loss: 0.2330 - val_accuracy: 0.9625
# Epoch 53/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.2666 - accuracy: 0.9278 - val_loss: 0.2622 - val_accuracy: 0.9250
# Epoch 54/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2471 - accuracy: 0.9361 - val_loss: 0.2284 - val_accuracy: 0.9625
# Epoch 55/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.2797 - accuracy: 0.9078 - val_loss: 0.2115 - val_accuracy: 0.9625
# Epoch 56/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2614 - accuracy: 0.9265 - val_loss: 0.2403 - val_accuracy: 0.9375
# Epoch 57/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.2503 - accuracy: 0.9349 - val_loss: 0.2037 - val_accuracy: 0.9875
# Epoch 58/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2542 - accuracy: 0.9132 - val_loss: 0.1816 - val_accuracy: 1.0000
# Epoch 59/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.2370 - accuracy: 0.9280 - val_loss: 0.1853 - val_accuracy: 0.9875
# Epoch 60/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1991 - accuracy: 0.9520 - val_loss: 0.1833 - val_accuracy: 0.9875
# Epoch 61/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.2235 - accuracy: 0.9387 - val_loss: 0.1660 - val_accuracy: 1.0000
# Epoch 62/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1750 - accuracy: 0.9609 - val_loss: 0.1688 - val_accuracy: 0.9875
# Epoch 63/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.2028 - accuracy: 0.9497 - val_loss: 0.1651 - val_accuracy: 1.0000
# Epoch 64/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2266 - accuracy: 0.9308 - val_loss: 0.1485 - val_accuracy: 1.0000
# Epoch 65/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1704 - accuracy: 0.9571 - val_loss: 0.1581 - val_accuracy: 1.0000
# Epoch 66/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2219 - accuracy: 0.9591 - val_loss: 0.1452 - val_accuracy: 1.0000
# Epoch 67/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1780 - accuracy: 0.9618 - val_loss: 0.1343 - val_accuracy: 1.0000
# Epoch 68/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.2054 - accuracy: 0.9575 - val_loss: 0.1276 - val_accuracy: 1.0000
# Epoch 69/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1858 - accuracy: 0.9548 - val_loss: 0.1246 - val_accuracy: 1.0000
# Epoch 70/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1635 - accuracy: 0.9678 - val_loss: 0.1223 - val_accuracy: 1.0000
# Epoch 71/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1567 - accuracy: 0.9574 - val_loss: 0.1283 - val_accuracy: 0.9875
# Epoch 72/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1674 - accuracy: 0.9730 - val_loss: 0.1392 - val_accuracy: 0.9750
# Epoch 73/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1422 - accuracy: 0.9739 - val_loss: 0.1168 - val_accuracy: 1.0000
# Epoch 74/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1667 - accuracy: 0.9564 - val_loss: 0.1060 - val_accuracy: 1.0000
# Epoch 75/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1391 - accuracy: 0.9662 - val_loss: 0.1065 - val_accuracy: 1.0000
# Epoch 76/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1436 - accuracy: 0.9651 - val_loss: 0.1021 - val_accuracy: 1.0000
# Epoch 77/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1312 - accuracy: 0.9845 - val_loss: 0.0968 - val_accuracy: 1.0000
# Epoch 78/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1502 - accuracy: 0.9593 - val_loss: 0.0888 - val_accuracy: 1.0000
# Epoch 79/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1182 - accuracy: 0.9759 - val_loss: 0.1136 - val_accuracy: 0.9875
# Epoch 80/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1344 - accuracy: 0.9619 - val_loss: 0.0827 - val_accuracy: 1.0000
# Epoch 81/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1152 - accuracy: 0.9819 - val_loss: 0.0818 - val_accuracy: 1.0000
# Epoch 82/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1094 - accuracy: 0.9895 - val_loss: 0.1020 - val_accuracy: 1.0000
# Epoch 83/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1229 - accuracy: 0.9747 - val_loss: 0.0740 - val_accuracy: 1.0000
# Epoch 84/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1383 - accuracy: 0.9607 - val_loss: 0.0779 - val_accuracy: 1.0000
# Epoch 85/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1144 - accuracy: 0.9885 - val_loss: 0.0772 - val_accuracy: 1.0000
# Epoch 86/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1173 - accuracy: 0.9792 - val_loss: 0.0846 - val_accuracy: 1.0000
# Epoch 87/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1063 - accuracy: 0.9824 - val_loss: 0.0721 - val_accuracy: 1.0000
# Epoch 88/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0960 - accuracy: 0.9841 - val_loss: 0.0685 - val_accuracy: 1.0000
# Epoch 89/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1361 - accuracy: 0.9668 - val_loss: 0.0673 - val_accuracy: 1.0000
# Epoch 90/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0870 - accuracy: 0.9860 - val_loss: 0.0650 - val_accuracy: 1.0000
# Epoch 91/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1179 - accuracy: 0.9694 - val_loss: 0.0973 - val_accuracy: 0.9625
# Epoch 92/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.1066 - accuracy: 0.9805 - val_loss: 0.0614 - val_accuracy: 1.0000
# Epoch 93/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0965 - accuracy: 0.9849 - val_loss: 0.0549 - val_accuracy: 1.0000
# Epoch 94/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0845 - accuracy: 0.9992 - val_loss: 0.0559 - val_accuracy: 1.0000
# Epoch 95/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0936 - accuracy: 0.9863 - val_loss: 0.0658 - val_accuracy: 1.0000
# Epoch 96/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0842 - accuracy: 0.9935 - val_loss: 0.0571 - val_accuracy: 1.0000
# Epoch 97/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0961 - accuracy: 0.9879 - val_loss: 0.0536 - val_accuracy: 1.0000
# Epoch 98/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0896 - accuracy: 0.9756 - val_loss: 0.0537 - val_accuracy: 1.0000
# Epoch 99/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0684 - accuracy: 0.9936 - val_loss: 0.0504 - val_accuracy: 1.0000
# Epoch 100/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0805 - accuracy: 0.9850 - val_loss: 0.0490 - val_accuracy: 1.0000
# Epoch 101/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.1072 - accuracy: 0.9689 - val_loss: 0.0490 - val_accuracy: 1.0000
# Epoch 102/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0712 - accuracy: 0.9812 - val_loss: 0.0455 - val_accuracy: 1.0000
# Epoch 103/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0612 - accuracy: 0.9969 - val_loss: 0.0411 - val_accuracy: 1.0000
# Epoch 104/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0768 - accuracy: 0.9821 - val_loss: 0.0424 - val_accuracy: 1.0000
# Epoch 105/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0832 - accuracy: 0.9874 - val_loss: 0.0473 - val_accuracy: 1.0000
# Epoch 106/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0694 - accuracy: 0.9795 - val_loss: 0.0446 - val_accuracy: 1.0000
# Epoch 107/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0729 - accuracy: 0.9896 - val_loss: 0.0394 - val_accuracy: 1.0000
# Epoch 108/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0784 - accuracy: 0.9919 - val_loss: 0.0380 - val_accuracy: 1.0000
# Epoch 109/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0575 - accuracy: 0.9941 - val_loss: 0.0376 - val_accuracy: 1.0000
# Epoch 110/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0698 - accuracy: 0.9870 - val_loss: 0.0335 - val_accuracy: 1.0000
# Epoch 111/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0517 - accuracy: 0.9979 - val_loss: 0.0369 - val_accuracy: 1.0000
# Epoch 112/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0711 - accuracy: 0.9827 - val_loss: 0.0349 - val_accuracy: 1.0000
# Epoch 113/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0619 - accuracy: 0.9936 - val_loss: 0.0417 - val_accuracy: 1.0000
# Epoch 114/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0709 - accuracy: 0.9908 - val_loss: 0.0324 - val_accuracy: 1.0000
# Epoch 115/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0528 - accuracy: 0.9995 - val_loss: 0.0373 - val_accuracy: 1.0000
# Epoch 116/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0611 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 1.0000
# Epoch 117/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0607 - accuracy: 0.9924 - val_loss: 0.0272 - val_accuracy: 1.0000
# Epoch 118/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0458 - accuracy: 0.9947 - val_loss: 0.0310 - val_accuracy: 1.0000
# Epoch 119/120
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0433 - accuracy: 0.9972 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 120/120
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0446 - accuracy: 0.9920 - val_loss: 0.0258 - val_accuracy: 1.0000
# Time elapsed for this training section: 292.83s

# %%
def plot_accuracy_loss(history):
    """
        Plot the accuracy and the loss during the training of the nn.
    """
    fig = plt.figure(figsize=(20,10))

    # Plot accuracy
    plt.subplot(221)
    plt.plot(history.history['accuracy'],'bo--', label = "acc")
    plt.plot(history.history['val_accuracy'], 'ro--', label = "val_acc")
    plt.title("train_acc vs val_acc")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()

    # Plot loss function
    plt.subplot(222)
    plt.plot(history.history['loss'],'bo--', label = "loss")
    plt.plot(history.history['val_loss'], 'ro--', label = "val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %%
plot_accuracy_loss(history)

# %%
loss, acc = model.evaluate(test_images, test_labels)

print("System Accuracy : {0:.2f}%".format(acc*100))
print("System Loss : {0:.5f}".format(loss))

# 30 Epochs, Accuracy = 83.75%
# 60 Epochs, Accuracy = 95.00%
# 90 Epochs, Accuracy = 97.50
# 120 Epochs Accuracy = 100%
# Out:
# 3/3 [==============================] - 1s 45ms/step - loss: 0.0366 - accuracy: 1.0000
# System Accuracy : 100.00%
# System Loss : 0.03664

# %%
predictions = model.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, test_images, pred_labels)

# %%
def print_mislabeled_images(class_names, test_images, test_labels, pred_labels):
    """
        Print 25 examples of mislabeled images by the classifier, e.g when test_labels != pred_labels
    """
    BOO = (test_labels == pred_labels)
    mislabeled_indices = np.where(BOO == 0)
    mislabeled_images = test_images[mislabeled_indices]
    mislabeled_labels = pred_labels[mislabeled_indices]

    title = "Some examples of mislabeled images by the classifier:"
    display_examples(class_names,  mislabeled_images, mislabeled_labels)

# %%
print_mislabeled_images(class_names, test_images, test_labels, pred_labels)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-40a0c23fa227> in <module>
# ----> 1 print_mislabeled_images(class_names, test_images, test_labels, pred_labels)
#
# <ipython-input-21-2b9596ee27de> in print_mislabeled_images(class_names, test_images, test_labels, pred_labels)
#       9
#      10     title = "Some examples of mislabeled images by the classifier:"
# ---> 11     display_examples(class_names,  mislabeled_images, mislabeled_labels)
#
# <ipython-input-12-cb91593e2983> in display_examples(class_names, images, labels)
#      11         plt.yticks([])
#      12         plt.grid(False)
# ---> 13         plt.imshow(images[i], cmap=plt.cm.binary)
#      14         plt.xlabel(class_names[labels[i]])
#      15     plt.show()
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sn.heatmap(CM, annot=True, 
           annot_kws={"size": 10}, 
           xticklabels=class_names, 
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()
